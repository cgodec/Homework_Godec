# %% [markdown]
# # Homework 3

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\crgod\anaconda_projects\fwe\data\MaunaLoaCO2_monthly_sitename.csv') #Imported data using file path
df.head() #Display first 5 rows
# Out:
#    Year  Month  Decimal_date  Monthly_average  deseasonalized  numofdays  \
# 0  1958      3     1958.2027           315.70          314.43         -1
# 1  1958      4     1958.2877           317.45          315.16         -1
# 2  1958      5     1958.3699           317.51          314.71         -1
# 3  1958      6     1958.4548           317.24          315.14         -1
# 4  1958      7     1958.5370           315.86          315.18         -1
#
#    stdofdays      site
# 0      -9.99  MaunaLoa
# 1      -9.99  MaunaLoa
# 2      -9.99  MaunaLoa
# 3      -9.99  MaunaLoa
# 4      -9.99  MaunaLoa

# %%
df1 = df[(df.Year !=1958) & #Set df1 equal to df where Year is not 1958
(df.Year!=2022) & #Set df1 equal to df where Year is not 2022
(df.numofdays>=0) & #Set df1 equal to df where Number of days is not negative
(df.stdofdays>=0)] #Set df1 equal to df where the std of days is not negative
df1
# Out:
#      Year  Month  Decimal_date  Monthly_average  deseasonalized  numofdays  \
# 194  1974      5     1974.3750           333.19          330.22         13
# 195  1974      6     1974.4583           332.20          329.78         25
# 196  1974      7     1974.5417           331.07          330.21         24
# 197  1974      8     1974.6250           329.15          330.54         26
# 198  1974      9     1974.7083           327.33          330.44         22
# ..    ...    ...           ...              ...             ...        ...
# 761  2021      8     2021.6250           414.47          416.49         26
# 762  2021      9     2021.7083           413.30          416.90         27
# 763  2021     10     2021.7917           413.93          417.30         29
# 764  2021     11     2021.8750           415.01          417.07         30
# 765  2021     12     2021.9583           416.71          417.44         28
#
#      stdofdays      site
# 194       0.31  MaunaLoa
# ...

# %%
df1['annual_average'] = df1.groupby('Year').Monthly_average.transform('mean') #Group by year and calculate mean of monthly average
df1['deseasonalized_annual_average'] = df.groupby('Year').deseasonalized.transform('mean') #Group by year and calculate mean of deseasonalized
df1['std_of_months'] = df.groupby('Year').Monthly_average.transform('std') #Group by year and calculate standard deviation of monthly average
df1
# Out:
# C:\Users\crgod\AppData\Local\Temp\ipykernel_17004\2889994879.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['annual_average'] = df1.groupby('Year').Monthly_average.transform('mean')
# C:\Users\crgod\AppData\Local\Temp\ipykernel_17004\2889994879.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['deseasonalized_annual_average'] = df.groupby('Year').deseasonalized.transform('mean')
# C:\Users\crgod\AppData\Local\Temp\ipykernel_17004\2889994879.py:3: SettingWithCopyWarning:
# ...

# %%
def CO2(val): #Define function
    if val < 350: 
        return 'Low' #If value is less than 350 return 'Low'
    elif val >= 350 and val <= 400: 
        return 'Moderate' #If value is greater than or equal to 350 and less than or equal to 400 return 'Moderate'
    else:
        return 'High' #If else return 'High'

df1['CO2_Category'] = df1.Monthly_average.apply(CO2) #Apply C02 function and store in new column 'CO2_Category' 
df1
# Out:
# C:\Users\crgod\AppData\Local\Temp\ipykernel_17004\1413597545.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['CO2_Category'] = df1.Monthly_average.apply(CO2)
#      Year  Month  Decimal_date  Monthly_average  deseasonalized  numofdays  \
# 194  1974      5     1974.3750           333.19          330.22         13
# 195  1974      6     1974.4583           332.20          329.78         25
# 196  1974      7     1974.5417           331.07          330.21         24
# 197  1974      8     1974.6250           329.15          330.54         26
# 198  1974      9     1974.7083           327.33          330.44         22
# ..    ...    ...           ...              ...             ...        ...
# ...

# %%
df1.to_csv('Godec_MaunaLoaCO2_annual_Hw3.csv', index=False)
